# %%
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import geopandas as gpd
import pyreadstat



def Lecturainicial(archivoexcel):
    pd.options.display.max_rows = None
    pd.options.display.max_columns = None
    print(archivoexcel)
    print(archivoexcel.columns)
def Distribucionporedadintenciondevoto(archivoexcel):
    temporal = archivoexcel[archivoexcel["EDAD"] == "16 a 25"]
    print(temporal)
    Grafico(temporal,archivoexcel)
    Ubicaciondeencuestados(temporal)
    temporal = archivoexcel[archivoexcel["EDAD"] == "26 a 35"]
    print(temporal)
    Grafico(temporal,archivoexcel)
    Ubicaciondeencuestados(temporal)
    temporal = archivoexcel[archivoexcel["EDAD"] == "36 a 45"]
    print(temporal)
    Grafico(temporal,archivoexcel)
    Ubicaciondeencuestados(temporal)
    temporal = archivoexcel[archivoexcel["EDAD"] == "46 a 55"]
    print(temporal)
    Grafico(temporal,archivoexcel)
    Ubicaciondeencuestados(temporal)
    temporal = archivoexcel[archivoexcel["EDAD"] == "56 y mas"]
    print(temporal)
    Grafico(temporal,archivoexcel)
    Ubicaciondeencuestados(temporal)

def Distribucionporgenerointenciondevoto(archivoexcel):
    temporal = pd.DataFrame
    temporal = archivoexcel[archivoexcel["GENERO"] == "Masculino"]
    print(temporal)
    Grafico(temporal,archivoexcel)
    Ubicaciondeencuestados(temporal)
    temporal = archivoexcel[archivoexcel["GENERO"] == "Femenino"]
    print(temporal)
    Grafico(temporal,archivoexcel)
    Ubicaciondeencuestados(temporal)
    temporal = archivoexcel[archivoexcel["GENERO"] == "Otro"]
    print(temporal)
    Grafico(temporal,archivoexcel)
    Ubicaciondeencuestados(temporal)

def Distribuciontotalintenciondevoto(archivoexcel):
      temporal = archivoexcel
      Grafico(temporal, archivoexcel)

def Grafico(temporal,archivoexcel):

    ## Convertir la frecuencia a un diccionario
    global paso
    paso = paso + 1
    frecuencia = temporal["INT DE VOTO X ESPACIO"].value_counts()
    diccionario_frecuencia = frecuencia.to_dict()
         #Extraer nombres (categorías) y valores (frecuencias)
    nombres = list(diccionario_frecuencia.keys())
    valores = list(diccionario_frecuencia.values())

        # Crear el gráfico de pastel
    plt.figure(figsize=(8, 8))
    plt.pie(
        valores,
        labels=nombres,
        autopct='%1.1f%%',  # Mostrar porcentajes
        )
    if paso == 1:
        plt.title("Intención de voto total sin clasificación")
    if paso == 2:
        plt.title("Intención de voto 16 a 25")
    if paso == 3:
        plt.title("Intención de voto 26 a 35")
    if paso == 4:
        plt.title("Intención de voto 36 a 45")
    if paso == 5:
        plt.title("Intención de voto 46 a 55")
    if paso == 6:
        plt.title("Intención de voto 56 y mas")
    if paso == 7:
        plt.title("Intención de voto Masculino")
    if paso == 8:
        plt.title("Intención de voto Femenino")
    if paso == 9:
        plt.title("Intención de voto Otros")

    plt.show()


def Ubicaciondeencuestados(temporal):
    global pasoubicacion
    pasoubicacion = pasoubicacion + 1
    gdf = gpd.GeoDataFrame(
        temporal, geometry=gpd.points_from_xy(x=temporal.Coord1__Longitude, y=temporal.Coord1__Latitude)
    )

    dfeliminado = gdf
    print(dfeliminado)
    var = dfeliminado["INT DE VOTO X ESPACIO"]
    ax = dfeliminado.plot(column=var, legend = True, figsize = (10,10))
    
    if pasoubicacion == 1:
        plt.title("Ubicación de los encuestados y sus intenciones de votos")
    if pasoubicacion == 2:
        plt.title("Ubicación de los encuestados y sus intenciones de votos de 16 a 25")
    if pasoubicacion == 3:
        plt.title("Ubicación de los encuestados y sus intenciones de votos de 26 a 35")
    if pasoubicacion == 4:
        plt.title("Ubicación de los encuestados y sus intenciones de votos de 36 a 45")
    if pasoubicacion == 5:
        plt.title("Ubicación de los encuestados y sus intenciones de votos de 46 a 55")
    if pasoubicacion == 6:
        plt.title("Ubicación de los encuestados y sus intenciones de votos de 56 a más")
    if pasoubicacion == 7:
        plt.title("Ubicación de los encuestados y sus intenciones de votos Masculino")
    if pasoubicacion == 8:
        plt.title("Ubicación de los encuestados y sus intenciones de votos Femenino")
    if pasoubicacion == 9:
        plt.title("Ubicación de los encuestados y sus intenciones de votos Otros")
    plt.show()

def Ubicacionporpartidopolitico(archivoexcel):
    temporal = archivoexcel[archivoexcel["INT DE VOTO X ESPACIO"] == "FdT"]
    print(temporal)
    Ubicaciondeencuestados(temporal)
    temporal = archivoexcel[archivoexcel["INT DE VOTO X ESPACIO"] == "JxC"]
    print(temporal)
    Ubicaciondeencuestados(temporal)
    temporal = archivoexcel[archivoexcel["INT DE VOTO X ESPACIO"] == "FIT"]
    print(temporal)
    Ubicaciondeencuestados(temporal)
    temporal = archivoexcel[archivoexcel["INT DE VOTO X ESPACIO"] == "NINGUNO/NOSABE"]
    print(temporal)
    Ubicaciondeencuestados(temporal)
    temporal = archivoexcel[archivoexcel["INT DE VOTO X ESPACIO"] == "PNK"]
    print(temporal)
    Ubicaciondeencuestados(temporal)
    temporal = archivoexcel[archivoexcel["INT DE VOTO X ESPACIO"] == "LIBERTARIOS"]
    print(temporal)
    Ubicaciondeencuestados(temporal)
    temporal = archivoexcel[archivoexcel["INT DE VOTO X ESPACIO"] == "OTROS"]
    print(temporal)
    Ubicaciondeencuestados(temporal)

archivoexcel = pd.read_excel("C:/Rosario F.xlsx")
archivoexcel = archivoexcel.drop([175], axis = 0)
paso = 0
pasoubicacion = 0
Lecturainicial(archivoexcel)
Ubicaciondeencuestados(archivoexcel)
Distribuciontotalintenciondevoto(archivoexcel)
Distribucionporedadintenciondevoto(archivoexcel)
Distribucionporgenerointenciondevoto(archivoexcel)
Ubicacionporpartidopolitico(archivoexcel)
# Out:
#     interview__key METODO  Coord1__Latitude  Coord1__Longitude      EDAD  \
# 0      56-56-25-81    F2F        -32.881458         -60.695274  56 y mas
# 1      67-96-98-06    F2F        -32.882259         -60.693571   36 a 45
# 2      24-21-01-39    F2F        -32.884731         -60.692882  56 y mas
# 3      84-96-80-81    F2F        -32.884673         -60.693464   26 a 35
# 4      21-29-79-64    F2F        -32.918833         -60.703628   36 a 45
# 5      16-53-72-77    F2F        -32.918831         -60.701551   46 a 55
# 6      33-52-26-63    F2F        -32.919319         -60.701945  56 y mas
# 7      97-65-95-19    F2F        -32.919283         -60.702176  56 y mas
# 8      60-33-90-60    F2F        -32.920606         -60.700574   26 a 35
# 9      80-36-02-32    F2F        -32.920734         -60.703901   46 a 55
# 10     88-84-75-28    F2F        -32.920294         -60.703054   26 a 35
# 11     94-39-26-50    F2F        -32.920758         -60.703289   26 a 35
# ...
